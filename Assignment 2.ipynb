# %%
from tkinter import *
from PIL import Image,ImageTk

# %%
my_window = Tk()
my_canvas = Canvas(my_window, width=900, height=350, background='green')
my_canvas.grid(row=0,column=0)

my_canvas.create_rectangle(0, 0, 100, 350, fill="blue")#endzone color
my_canvas.create_rectangle(800, 0, 900, 350, fill="blue")#endzone color

#NFL logo
img=ImageTk.PhotoImage(file="desktop/NFL2.png")
my_canvas.create_image(425,140,anchor= NW,image=img)#NFL logo

#Endzone team
my_canvas.create_text(50,175,fill='grey',font="Times 40 bold",text="Dallas", angle=90)
my_canvas.create_text(860,175,fill='grey',font="Times 40 bold",text="Cowboys", angle=270)

#Yardage lines
my_canvas.create_line(100,0,100,840,fill='white',width=5)
my_canvas.create_line(170,0,170,840,fill='white',width=5)
my_canvas.create_line(240,0,240,840,fill='white',width=5)
my_canvas.create_line(310,0,310,840,fill='white',width=5)
my_canvas.create_line(380,0,380,840,fill='white',width=5)
my_canvas.create_line(450,0,450,140,fill='white',width=5)
my_canvas.create_line(450,350,450,210,fill='white',width=5)
my_canvas.create_line(520,0,520,840,fill='white',width=5)
my_canvas.create_line(590,0,590,840,fill='white',width=5)
my_canvas.create_line(660,0,660,840,fill='white',width=5)
my_canvas.create_line(730,0,730,840,fill='white',width=5)
my_canvas.create_line(800,0,800,840,fill='white',width=5)

#Yardage harsh marks, 2 yard incraments
#between 0-10 yardline
my_canvas.create_line(114,15,114,0,fill='white',width=5)
my_canvas.create_line(128,15,128,0,fill='white',width=5)
my_canvas.create_line(142,15,142,0,fill='white',width=5)
my_canvas.create_line(156,15,156,0,fill='white',width=5)
my_canvas.create_line(744,15,744,0,fill='white',width=5)
my_canvas.create_line(758,15,758,0,fill='white',width=5)
my_canvas.create_line(772,15,772,0,fill='white',width=5)
my_canvas.create_line(786,15,786,0,fill='white',width=5)

my_canvas.create_line(114,335,114,840,fill='white',width=5)
my_canvas.create_line(128,335,128,840,fill='white',width=5)
my_canvas.create_line(142,335,142,840,fill='white',width=5)
my_canvas.create_line(156,335,156,840,fill='white',width=5)
my_canvas.create_line(744,335,744,840,fill='white',width=5)
my_canvas.create_line(758,335,758,840,fill='white',width=5)
my_canvas.create_line(772,335,772,840,fill='white',width=5)
my_canvas.create_line(786,335,786,840,fill='white',width=5)

#between 10-20 yardline
my_canvas.create_line(184,15,184,0,fill='white',width=5)
my_canvas.create_line(198,15,198,0,fill='white',width=5)
my_canvas.create_line(212,15,212,0,fill='white',width=5)
my_canvas.create_line(226,15,226,0,fill='white',width=5)
my_canvas.create_line(674,15,674,0,fill='white',width=5)
my_canvas.create_line(688,15,688,0,fill='white',width=5)
my_canvas.create_line(702,15,702,0,fill='white',width=5)
my_canvas.create_line(716,15,716,0,fill='white',width=5)

my_canvas.create_line(184,335,184,840,fill='white',width=5)
my_canvas.create_line(198,335,198,840,fill='white',width=5)
my_canvas.create_line(212,335,212,840,fill='white',width=5)
my_canvas.create_line(226,335,226,840,fill='white',width=5)
my_canvas.create_line(674,335,674,840,fill='white',width=5)
my_canvas.create_line(688,335,688,840,fill='white',width=5)
my_canvas.create_line(702,335,702,840,fill='white',width=5)
my_canvas.create_line(716,335,716,840,fill='white',width=5)

#between 20-30 yardline
my_canvas.create_line(254,15,254,0,fill='white',width=5)
my_canvas.create_line(268,15,268,0,fill='white',width=5)
my_canvas.create_line(282,15,282,0,fill='white',width=5)
my_canvas.create_line(296,15,296,0,fill='white',width=5)
my_canvas.create_line(604,15,604,0,fill='white',width=5)
my_canvas.create_line(618,15,618,0,fill='white',width=5)
my_canvas.create_line(632,15,632,0,fill='white',width=5)
my_canvas.create_line(646,15,646,0,fill='white',width=5)

my_canvas.create_line(254,335,254,840,fill='white',width=5)
my_canvas.create_line(268,335,268,840,fill='white',width=5)
my_canvas.create_line(282,335,282,840,fill='white',width=5)
my_canvas.create_line(296,335,296,840,fill='white',width=5)
my_canvas.create_line(604,335,604,840,fill='white',width=5)
my_canvas.create_line(618,335,618,840,fill='white',width=5)
my_canvas.create_line(632,335,632,840,fill='white',width=5)
my_canvas.create_line(646,335,646,840,fill='white',width=5)

#between 30-40 yardline
my_canvas.create_line(324,15,324,0,fill='white',width=5)
my_canvas.create_line(338,15,338,0,fill='white',width=5)
my_canvas.create_line(352,15,352,0,fill='white',width=5)
my_canvas.create_line(366,15,366,0,fill='white',width=5)
my_canvas.create_line(534,15,534,0,fill='white',width=5)
my_canvas.create_line(548,15,548,0,fill='white',width=5)
my_canvas.create_line(562,15,562,0,fill='white',width=5)
my_canvas.create_line(576,15,576,0,fill='white',width=5)

my_canvas.create_line(324,335,324,840,fill='white',width=5)
my_canvas.create_line(338,335,338,840,fill='white',width=5)
my_canvas.create_line(352,335,352,840,fill='white',width=5)
my_canvas.create_line(366,335,366,840,fill='white',width=5)
my_canvas.create_line(534,335,534,840,fill='white',width=5)
my_canvas.create_line(548,335,548,840,fill='white',width=5)
my_canvas.create_line(562,335,562,840,fill='white',width=5)
my_canvas.create_line(576,335,576,840,fill='white',width=5)


#between 40-50 yardline
my_canvas.create_line(394,15,394,0,fill='white',width=5)
my_canvas.create_line(408,15,408,0,fill='white',width=5)
my_canvas.create_line(422,15,422,0,fill='white',width=5)
my_canvas.create_line(436,15,436,0,fill='white',width=5)
my_canvas.create_line(464,15,464,0,fill='white',width=5)
my_canvas.create_line(478,15,478,0,fill='white',width=5)
my_canvas.create_line(492,15,492,0,fill='white',width=5)
my_canvas.create_line(506,15,506,0,fill='white',width=5)

my_canvas.create_line(394,335,394,840,fill='white',width=5)
my_canvas.create_line(408,335,408,840,fill='white',width=5)
my_canvas.create_line(422,335,422,840,fill='white',width=5)
my_canvas.create_line(436,335,436,840,fill='white',width=5)
my_canvas.create_line(464,335,464,840,fill='white',width=5)
my_canvas.create_line(478,335,478,840,fill='white',width=5)
my_canvas.create_line(492,335,492,840,fill='white',width=5)
my_canvas.create_line(506,335,506,840,fill='white',width=5)

#Out of bounds lines
my_canvas.create_line(0,350,900,350,fill='white',width=10)
my_canvas.create_line(900,350,900,0,fill='white',width=10)
my_canvas.create_line(900,0,0,0,fill='white',width=10)
my_canvas.create_line(0,0,0,350,fill='white',width=10)


#Slideline number for home side
my_canvas.create_text(185,280,fill='white',font="Times 15 bold",text="10", angle=180)
my_canvas.create_text(255,280,fill='white',font="Times 15 bold",text="20", angle=180)
my_canvas.create_text(325,280,fill='white',font="Times 15 bold",text="30", angle=180)
my_canvas.create_text(405,280,fill='white',font="Times 15 bold",text="40", angle=180)
my_canvas.create_text(475,280,fill='white',font="Times 15 bold",text="50", angle=180)
my_canvas.create_text(545,280,fill='white',font="Times 15 bold",text="40", angle=180)
my_canvas.create_text(615,280,fill='white',font="Times 15 bold",text="30", angle=180)
my_canvas.create_text(685,280,fill='white',font="Times 15 bold",text="20", angle=180)
my_canvas.create_text(755,280,fill='white',font="Times 15 bold",text="10", angle=180)

#Slideline number for away side
my_canvas.create_text(185,70,fill='white',font="Times 15 bold",text="10")
my_canvas.create_text(255,70,fill='white',font="Times 15 bold",text="20")
my_canvas.create_text(325,70,fill='white',font="Times 15 bold",text="30")
my_canvas.create_text(405,70,fill='white',font="Times 15 bold",text="40")
my_canvas.create_text(475,70,fill='white',font="Times 15 bold",text="50")
my_canvas.create_text(545,70,fill='white',font="Times 15 bold",text="40")
my_canvas.create_text(615,70,fill='white',font="Times 15 bold",text="30")
my_canvas.create_text(685,70,fill='white',font="Times 15 bold",text="20")
my_canvas.create_text(755,70,fill='white',font="Times 15 bold",text="10")

my_window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 9>()
#       6 my_canvas.create_rectangle(800, 0, 900, 350, fill="blue")#endzone color
#       8 #NFL logo
# ----> 9 img=ImageTk.PhotoImage(file="desktop/NFL2.png")
#      10 my_canvas.create_image(425,140,anchor= NW,image=img)#NFL logo
#      12 #Endzone team
#
# File ~\anaconda3\envs\Sports\lib\site-packages\PIL\ImageTk.py:117, in PhotoImage.__init__(self, image, size, **kw)
#     113 def __init__(self, image=None, size=None, **kw):
#     114
#     115     # Tk compatibility: file or data
#     116     if image is None:
# --> 117         image = _get_image_from_kw(kw)
#     119     if hasattr(image, "mode") and hasattr(image, "size"):
#     120         # got an image instead of a mode
#     121         mode = image.mode
#
# ...

# %%
#citation:
#https://stackoverflow.com/questions/9886274/how-can-i-convert-canvas-content-to-an-image
#https://www.youtube.com/watch?v=2rF8-jbTL-8
#http://www.pythonbytesize.com/video-index.html
